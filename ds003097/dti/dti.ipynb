# %%
import nibabel as nib
import os
from neurotools.plotting import plot
from nilearn.image import resample_to_img
from nilearn.datasets import load_mni152_template

template = load_mni152_template()

# %%
ex = '/home/sage/methods_series/data/ds003097/derivatives/dwipreproc/sub-0001/dwi/'
file = 'sub-0001_model-DTI_desc-WLS_FA.nii.gz'

data = nib.load(os.path.join(ex, file))
plot(data)

# %%
resampled_stat_img = resample_to_img(data, template)

# %%
plot(resampled_stat_img)
